# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from scipy.spatial import ConvexHull


# Reading the data set file

data_set = pd.read_csv("data_set.csv") 

# dropping unnecessary elements form the dataset file

data_set = data_set.drop(["s_duration",
                          "e_codec",
                          "e_codec_profile",
                          "e_scan_type",
                          "e_pixel_aspect_ratio",
                          "e_pixel_fmt",
                          "e_aspect_ratio",
                          "e_b_frame_int",
                          "e_ref_frame_count",
                          "t_average_vmaf_mobile",
                          "e_bit_depth",
                          "t_average_vmaf_4k",
                          "t_average_psnr",
                          "s_scan_type"], axis=1)
# data_set.head()

# make our content categories unique
uniq = data_set['c_content_category'].unique()

# %% [markdown]
# #  *** plot 15 RD curves based on VMAF ***

# %%
FIGURE, ax = plt.subplots(5, 3,figsize=(15,15))

# Summerize values which is sorted in uniq

summerize = data_set[data_set['c_content_category'] == uniq[0]]

# Get the unique width from our dataset

resoluion_lst = summerize['e_width'].unique()

for i in resoluion_lst:
        resoluion = summerize[summerize['e_width'] == i]
        resoluion = resoluion.sort_values(by=['t_average_bitrate'])
        x = resoluion['t_average_bitrate']
        y = resoluion['t_average_vmaf']
        ax[0, 0].plot(x, y, label=i)
        ax[0, 0].set_xlabel('Average_Bitrate')
        ax[0, 0].set_ylabel('Average_VMAF')
        ax[0, 0].title.set_text(uniq[0])


summerize=data_set[data_set['c_content_category'] == uniq[1]]
resoluion_lst = summerize['e_width'].unique()
for i in resoluion_lst:
        resoluion = summerize[summerize['e_width'] == i]
        resoluion = resoluion.sort_values(by=['t_average_bitrate'])
        x = resoluion['t_average_bitrate']
        y = resoluion['t_average_vmaf']
        ax[1, 0].plot(x, y, label=i)
        ax[1, 0].set_xlabel('Average_Bitrate')
        ax[1, 0].set_ylabel('Average_VMAF')
        ax[1, 0].title.set_text(uniq[1])


summerize=data_set[data_set['c_content_category'] == uniq[2]]
resoluion_lst = summerize['e_width'].unique()
for i in resoluion_lst:
        resoluion = summerize[summerize['e_width'] == i]
        resoluion = resoluion.sort_values(by=['t_average_bitrate'])
        x = resoluion['t_average_bitrate']
        y = resoluion['t_average_vmaf']
        ax[2, 0].plot(x, y, label=i)
        ax[2, 0].set_xlabel('Average_Bitrate')
        ax[2, 0].set_ylabel('Average_VMAF')
        ax[2, 0].title.set_text(uniq[2])

        

summerize=data_set[data_set['c_content_category'] == uniq[3]]
resoluion_lst = summerize['e_width'].unique()
for i in resoluion_lst:
        resoluion = summerize[summerize['e_width'] == i]
        resoluion = resoluion.sort_values(by=['t_average_bitrate'])
        x = resoluion['t_average_bitrate']
        y = resoluion['t_average_vmaf']
        ax[3, 0].plot(x, y, label=i)
        ax[3, 0].set_xlabel('Average_Bitrate')
        ax[3, 0].set_ylabel('Average_VMAF')
        ax[3, 0].title.set_text(uniq[3])



summerize = data_set[data_set['c_content_category'] == uniq[4]]
resoluion_lst = summerize['e_width'].unique()
for i in resoluion_lst:
        resoluion = summerize[summerize['e_width'] == i]
        resoluion = resoluion.sort_values(by=['t_average_bitrate'])
        x = resoluion['t_average_bitrate']
        y = resoluion['t_average_vmaf']
        ax[4, 0].plot(x, y, label=i)
        ax[4, 0].set_xlabel('Average_Bitrate')
        ax[4, 0].set_ylabel('Average_VMAF')
        ax[4, 0].title.set_text(uniq[4])
        

summerize = data_set[data_set['c_content_category'] == uniq[5]]
resoluion_lst = summerize['e_width'].unique()
for i in resoluion_lst:
        resoluion = summerize[summerize['e_width'] == i]
        resoluion = resoluion.sort_values(by=['t_average_bitrate'])
        x = resoluion['t_average_bitrate']
        y = resoluion['t_average_vmaf']
        ax[0, 1].plot(x, y, label=i)
        ax[0, 1].set_xlabel('Average_Bitrate')
        ax[0, 1].set_ylabel('Average_VMAF')
        ax[0, 1].title.set_text(uniq[5])


summerize = data_set[data_set['c_content_category'] == uniq[6]]
resoluion_lst = summerize['e_width'].unique()
for i in resoluion_lst:
        resoluion = summerize[summerize['e_width'] == i]
        resoluion = resoluion.sort_values(by=['t_average_bitrate'])
        x = resoluion['t_average_bitrate']
        y = resoluion['t_average_vmaf']
        ax[1, 1].plot(x, y, label=i)
        ax[1, 1].set_xlabel('Average_Bitrate')
        ax[1, 1].set_ylabel('Average_VMAF')
        ax[1, 1].title.set_text(uniq[6])
        

summerize=data_set[data_set['c_content_category'] == uniq[7]]
resoluion_lst = summerize['e_width'].unique()
for i in resoluion_lst:
        resoluion = summerize[summerize['e_width'] == i]
        resoluion = resoluion.sort_values(by=['t_average_bitrate'])
        x = resoluion['t_average_bitrate']
        y = resoluion['t_average_vmaf']
        ax[2, 1].plot(x, y, label=i)
        ax[2, 1].set_xlabel('Average_Bitrate')
        ax[2, 1].set_ylabel('Average_VMAF')
        ax[2, 1].title.set_text(uniq[7])
        

summerize=data_set[data_set['c_content_category'] == uniq[8]]
resoluion_lst = summerize['e_width'].unique()
for i in resoluion_lst:
        resoluion = summerize[summerize['e_width'] == i]
        resoluion = resoluion.sort_values(by=['t_average_bitrate'])
        x = resoluion['t_average_bitrate']
        y = resoluion['t_average_vmaf']
        ax[3, 1].plot(x, y, label=i)
        ax[3, 1].set_xlabel('Average_Bitrate')
        ax[3, 1].set_ylabel('Average_VMAF')
        ax[3, 1].title.set_text(uniq[8])
        

summerize=data_set[data_set['c_content_category'] == uniq[9]]
resoluion_lst = summerize['e_width'].unique()
for i in resoluion_lst:
        resoluion = summerize[summerize['e_width'] == i]
        resoluion = resoluion.sort_values(by=['t_average_bitrate'])
        x = resoluion['t_average_bitrate']
        y = resoluion['t_average_vmaf']
        ax[4, 1].plot(x, y, label=i)
        ax[4, 1].set_xlabel('Average_Bitrate')
        ax[4, 1].set_ylabel('Average_VMAF')
        ax[4, 1].title.set_text(uniq[9])
        

summerize=data_set[data_set['c_content_category'] == uniq[10]]
resoluion_lst = summerize['e_width'].unique()
for i in resoluion_lst:
        resoluion = summerize[summerize['e_width'] == i]
        resoluion = resoluion.sort_values(by=['t_average_bitrate'])
        x = resoluion['t_average_bitrate']
        y = resoluion['t_average_vmaf']
        ax[0, 2].plot(x, y, label=i)
        ax[0, 2].set_xlabel('Average_Bitrate')
        ax[0, 2].set_ylabel('Average_VMAF')
        ax[0, 2].title.set_text(uniq[10])
        

summerize=data_set[data_set['c_content_category']==uniq[11]]
resoluion_lst = summerize['e_width'].unique()
for i in resoluion_lst:
        resoluion = summerize[summerize['e_width']==i]
        resoluion = resoluion.sort_values(by=['t_average_bitrate'])
        x = resoluion['t_average_bitrate']
        y = resoluion['t_average_vmaf']
        ax[1, 2].plot(x, y, label=i)
        ax[1, 2].set_xlabel('Average_Bitrate')
        ax[1, 2].set_ylabel('Average_VMAF')
        ax[1, 2].title.set_text(uniq[11])
        

summerize=data_set[data_set['c_content_category']==uniq[12]]
resoluion_lst = summerize['e_width'].unique()
for i in resoluion_lst:
        resoluion = summerize[summerize['e_width']==i]
        resoluion = resoluion.sort_values(by=['t_average_bitrate'])
        x = resoluion['t_average_bitrate']
        y = resoluion['t_average_vmaf']
        ax[2, 2].plot(x, y, label=i)
        ax[2, 2].set_xlabel('Average_Bitrate')
        ax[2, 2].set_ylabel('Average_VMAF')
        ax[2, 2].title.set_text(uniq[12])
        

summerize=data_set[data_set['c_content_category']==uniq[13]]
resoluion_lst = summerize['e_width'].unique()
for i in resoluion_lst:
        resoluion = summerize[summerize['e_width']==i]
        resoluion = resoluion.sort_values(by=['t_average_bitrate'])
        x = resoluion['t_average_bitrate']
        y = resoluion['t_average_vmaf']
        ax[3, 2].plot(x, y, label=i)
        ax[3, 2].set_xlabel('Average_Bitrate')
        ax[3, 2].set_ylabel('Average_VMAF')
        ax[3, 2].title.set_text(uniq[13])

        
        
plt.legend(title='Resolution')
plt.tight_layout()


summerize=data_set[data_set['c_content_category']==uniq[14]]
resoluion_lst = summerize['e_width'].unique()
for i in resoluion_lst:
        Res = summerize[summerize['e_width']==i]
        Res = Res.sort_values(by=['t_average_bitrate'])
        x = Res['t_average_bitrate']
        y = Res['t_average_vmaf']
        ax[4, 2].plot(x, y, label=i)
        ax[4, 2].set_xlabel('Average_Bitrate')
        ax[4, 2].set_ylabel('Average_VMAF')
        ax[4, 2].title.set_text(uniq[14])
        


plt.legend(title='Resolution')
plt.tight_layout()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Convex Hull on our RD Curves (15)

# %%
FIGURE, ax = plt.subplots(5, 3,figsize=(15,15))


# This convex hull for this axis is inconsistent

''' summerize=data_set[data_set['c_content_category']==uniq[0]] 
resoluion_lst = summerize['e_width'].unique() 


for i in resoluion_lst:
        Res = summerize[summerize['e_width']==i]
        Res = Res.sort_values(by=['t_average_bitrate'])
        x = Res['t_average_bitrate']
        y = Res['t_average_vmaf']
        ax[0, 0].plot(x, y, label=i)
        ax[0, 0].title.set_text(uniq[0])
                        
# finding x and y axis for our convex hull


x = summerize['t_average_bitrate']
y = summerize['t_average_vmaf']
x_lst = pd.Series(x).values
y_lst = pd.Series(y).values
x_lst_S = x_lst.reshape(312,1)
y_lst_S = y_lst.reshape(312,1)
xy = np.concatenate((x_lst_S, y_lst_S), axis=1)

# plot convex hull for axis

hull = ConvexHull(xy)
for sample in hull.simplices:
    ax[0, 0].plot(xy[sample, 0], xy[sample, 1], 'r', label=i, linewidth=2)'''



summerize=data_set[data_set['c_content_category']==uniq[1]]
resoluion_lst = summerize['e_width'].unique()

for i in resoluion_lst:
        Res = summerize[summerize['e_width']==i]
        Res = Res.sort_values(by=['t_average_bitrate'])
        x = Res['t_average_bitrate']
        y = Res['t_average_vmaf']
        ax[1, 0].plot(x, y, label=i)
        ax[1, 0].title.set_text(uniq[1])
                        
# finding x and y axis for our convex hull

x = summerize['t_average_bitrate']
y = summerize['t_average_vmaf']
x_lst = pd.Series(x).values
y_lst = pd.Series(y).values
x_lst_S = x_lst.reshape(78,1)
y_lst_S = y_lst.reshape(78,1)
xy = np.concatenate((x_lst_S, y_lst_S), axis=1)


# plot convex hull for axis

hull = ConvexHull(xy)
for sample in hull.simplices:
    ax[1, 0].plot(xy[sample, 0], xy[sample, 1], 'r', label=i, linewidth=2)




summerize=data_set[data_set['c_content_category']==uniq[2]]
resoluion_lst = summerize['e_width'].unique()


for i in resoluion_lst:
        Res = summerize[summerize['e_width']==i]
        Res = Res.sort_values(by=['t_average_bitrate'])
        x = Res['t_average_bitrate']
        y = Res['t_average_vmaf']
        ax[2, 0].plot(x, y, label=i)
        ax[2, 0].title.set_text(uniq[2])
                        
# finding x and y axis for our convex hull

x = summerize['t_average_bitrate']
y = summerize['t_average_vmaf']
x_lst = pd.Series(x).values
y_lst = pd.Series(y).values
x_lst_S = x_lst.reshape(546,1)
y_lst_S = y_lst.reshape(546,1)
xy = np.concatenate((x_lst_S, y_lst_S), axis=1)


## plot convex hull for axis

hull = ConvexHull(xy)
for sample in hull.simplices:
    ax[2, 0].plot(xy[sample, 0], xy[sample, 1], 'r', label=i, linewidth=2)

        


summerize=data_set[data_set['c_content_category']==uniq[3]]
resoluion_lst = summerize['e_width'].unique()

for i in resoluion_lst:
        Res = summerize[summerize['e_width']==i]
        Res = Res.sort_values(by=['t_average_bitrate'])
        x = Res['t_average_bitrate']
        y = Res['t_average_vmaf']
        ax[3, 0].plot(x, y, label=i)
        ax[3, 0].title.set_text(uniq[3])
                        
# finding x and y axis for our convex hull

x = summerize['t_average_bitrate']
y = summerize['t_average_vmaf']
x_lst = pd.Series(x).values
y_lst = pd.Series(y).values
x_lst_S = x_lst.reshape(78,1)
y_lst_S = y_lst.reshape(78,1)
xy = np.concatenate((x_lst_S, y_lst_S), axis=1)


## plot convex hull for axis

hull = ConvexHull(xy)
for sample in hull.simplices:
    ax[3, 0].plot(xy[sample, 0], xy[sample, 1], 'r', label=i, linewidth=2)

# These values are inconsistent

'''summerize=data_set[data_set['c_content_category']==uniq[4]] 
resoluion_lst = summerize['e_width'].unique() 

for i in resoluion_lst:
        Res = summerize[summerize['e_width']==i]
        Res = Res.sort_values(by=['t_average_bitrate'])
        x = Res['t_average_bitrate']
        y = Res['t_average_vmaf']
        ax[4, 0].plot(x, y, label=i)
        ax[4, 0].title.set_text(uniq[0])
                        
# finding x and y axis for our convex hull

x = summerize['t_average_bitrate']
y = summerize['t_average_vmaf']
x_lst = pd.Series(x).values
y_lst = pd.Series(y).values
x_lst_S = x_lst.reshape(780,1)
y_lst_S = y_lst.reshape(780,1)
xy = np.concatenate((x_lst_S, y_lst_S), axis=1)


## plot convex hull for axis

hull = ConvexHull(xy)
for sample in hull.simplices:
    ax[4, 0].plot(xy[sample, 0], xy[sample, 1], 'r', label=i, linewidth=2) '''

    
    


summerize=data_set[data_set['c_content_category']==uniq[5]]
resoluion_lst = summerize['e_width'].unique()

for i in resoluion_lst:
        Res = summerize[summerize['e_width']==i]
        Res = Res.sort_values(by=['t_average_bitrate'])
        x = Res['t_average_bitrate']
        y = Res['t_average_vmaf']
        ax[0, 1].plot(x, y, label=i)
        ax[0, 1].title.set_text(uniq[0])
                        
# finding x and y axis for our convex hull

x = summerize['t_average_bitrate']
y = summerize['t_average_vmaf']
x_lst = pd.Series(x).values
y_lst = pd.Series(y).values
x_lst_S = x_lst.reshape(312,1)
y_lst_S = y_lst.reshape(312,1)
xy = np.concatenate((x_lst_S, y_lst_S), axis=1)


## plot convex hull for axis

hull = ConvexHull(xy)
for sample in hull.simplices:
    ax[0, 1].plot(xy[sample, 0], xy[sample, 1], 'r', label=i, linewidth=2)



summerize=data_set[data_set['c_content_category']==uniq[6]]
resoluion_lst = summerize['e_width'].unique()

for i in resoluion_lst:
        Res = summerize[summerize['e_width']==i]
        Res = Res.sort_values(by=['t_average_bitrate'])
        x = Res['t_average_bitrate']
        y = Res['t_average_vmaf']
        ax[1, 1].plot(x, y, label=i)
        ax[1, 1].title.set_text(uniq[6])
                        
# finding x and y axis for our convex hull

x = summerize['t_average_bitrate']
y = summerize['t_average_vmaf']
x_lst = pd.Series(x).values
y_lst = pd.Series(y).values
x_lst_S = x_lst.reshape(78,1)
y_lst_S = y_lst.reshape(78,1)
xy = np.concatenate((x_lst_S, y_lst_S), axis=1)


## plot convex hull for axis

hull = ConvexHull(xy)
for sample in hull.simplices:
    ax[1, 1].plot(xy[sample, 0], xy[sample, 1], 'r', label=i, linewidth=2)



summerize=data_set[data_set['c_content_category']==uniq[7]]
resoluion_lst = summerize['e_width'].unique()

for i in resoluion_lst:
        Res = summerize[summerize['e_width']==i]
        Res = Res.sort_values(by=['t_average_bitrate'])
        x = Res['t_average_bitrate']
        y = Res['t_average_vmaf']
        ax[2, 1].plot(x, y, label=i)
        ax[2, 1].title.set_text(uniq[7])
                        
# finding x and y axis for our convex hull

x = summerize['t_average_bitrate']
y = summerize['t_average_vmaf']
x_lst = pd.Series(x).values
y_lst = pd.Series(y).values
x_lst_S = x_lst.reshape(156,1)
y_lst_S = y_lst.reshape(156,1)
xy = np.concatenate((x_lst_S, y_lst_S), axis=1)


## plot convex hull for axis

hull = ConvexHull(xy)
for sample in hull.simplices:
    ax[2, 1].plot(xy[sample, 0], xy[sample, 1], 'r', label=i, linewidth=2)
        


summerize=data_set[data_set['c_content_category']==uniq[8]]
resoluion_lst = summerize['e_width'].unique()

for i in resoluion_lst:
        Res = summerize[summerize['e_width']==i]
        Res = Res.sort_values(by=['t_average_bitrate'])
        x = Res['t_average_bitrate']
        y = Res['t_average_vmaf']
        ax[3, 1].plot(x, y, label=i)
        ax[3, 1].title.set_text(uniq[8])
                        
# finding x and y axis for our convex hull

x = summerize['t_average_bitrate']
y = summerize['t_average_vmaf']
x_lst = pd.Series(x).values
y_lst = pd.Series(y).values
x_lst_S = x_lst.reshape(78,1)
y_lst_S = y_lst.reshape(78,1)
xy = np.concatenate((x_lst_S, y_lst_S), axis=1)


## plot convex hull for axis

hull = ConvexHull(xy)
for sample in hull.simplices:
    ax[3, 1].plot(xy[sample, 0], xy[sample, 1], 'r', label=i, linewidth=2)
               



summerize=data_set[data_set['c_content_category']==uniq[9]]
resoluion_lst = summerize['e_width'].unique()

for i in resoluion_lst:
        Res = summerize[summerize['e_width']==i]
        Res = Res.sort_values(by=['t_average_bitrate'])
        x = Res['t_average_bitrate']
        y = Res['t_average_vmaf']
        ax[4, 1].plot(x, y, label=i)
        ax[4, 1].title.set_text(uniq[9])
                        
# finding x and y axis for our convex hull

x = summerize['t_average_bitrate']
y = summerize['t_average_vmaf']
x_lst = pd.Series(x).values
y_lst = pd.Series(y).values
x_lst_S = x_lst.reshape(78,1)
y_lst_S = y_lst.reshape(78,1)
xy = np.concatenate((x_lst_S, y_lst_S), axis=1)


## plot convex hull for axis

hull = ConvexHull(xy)
for sample in hull.simplices:
    ax[4, 1].plot(xy[sample, 0], xy[sample, 1], 'r', label=i, linewidth=2)
               


summerize=data_set[data_set['c_content_category']==uniq[10]]
resoluion_lst = summerize['e_width'].unique()

for i in resoluion_lst:
        Res = summerize[summerize['e_width']==i]
        Res = Res.sort_values(by=['t_average_bitrate'])
        x = Res['t_average_bitrate']
        y = Res['t_average_vmaf']
        ax[0, 2].plot(x, y, label=i)
        ax[0, 2].title.set_text(uniq[10])
                        
# finding x and y axis for our convex hull

x = summerize['t_average_bitrate']
y = summerize['t_average_vmaf']
x_lst = pd.Series(x).values
y_lst = pd.Series(y).values
x_lst_S = x_lst.reshape(78,1)
y_lst_S = y_lst.reshape(78,1)
xy = np.concatenate((x_lst_S, y_lst_S), axis=1)


## plot convex hull for axis

hull = ConvexHull(xy)
for sample in hull.simplices:
    ax[0, 2].plot(xy[sample, 0], xy[sample, 1], 'r', label=i, linewidth=2)
        


summerize=data_set[data_set['c_content_category']==uniq[11]]
resoluion_lst = summerize['e_width'].unique()

for i in resoluion_lst:
        Res = summerize[summerize['e_width']==i]
        Res = Res.sort_values(by=['t_average_bitrate'])
        x = Res['t_average_bitrate']
        y = Res['t_average_vmaf']
        ax[1, 2].plot(x, y, label=i)
        ax[1, 2].title.set_text(uniq[11])
                        
# finding x and y axis for our convex hull

x = summerize['t_average_bitrate']
y = summerize['t_average_vmaf']
x_lst = pd.Series(x).values
y_lst = pd.Series(y).values
x_lst_S = x_lst.reshape(78,1)
y_lst_S = y_lst.reshape(78,1)
xy = np.concatenate((x_lst_S, y_lst_S), axis=1)


# plot convex hull for axis

hull = ConvexHull(xy)
for sample in hull.simplices:
    ax[1, 2].plot(xy[sample, 0], xy[sample, 1], 'r', label=i, linewidth=2)
        


summerize=data_set[data_set['c_content_category']==uniq[12]]
resoluion_lst = summerize['e_width'].unique()

for i in resoluion_lst:
        Res = summerize[summerize['e_width']==i]
        Res = Res.sort_values(by=['t_average_bitrate'])
        x = Res['t_average_bitrate']
        y = Res['t_average_vmaf']
        ax[2, 2].plot(x, y, label=i)
        ax[2, 2].title.set_text(uniq[12])
                        
# finding x and y axis for our convex hull

x = summerize['t_average_bitrate']
y = summerize['t_average_vmaf']
x_lst = pd.Series(x).values
y_lst = pd.Series(y).values
x_lst_S = x_lst.reshape(312,1)
y_lst_S = y_lst.reshape(312,1)
xy = np.concatenate((x_lst_S, y_lst_S), axis=1)


# plot convex hull for axis

hull = ConvexHull(xy)
for sample in hull.simplices:
    ax[2, 2].plot(xy[sample, 0], xy[sample, 1], 'r', label=i, linewidth=2)
        


summerize=data_set[data_set['c_content_category']==uniq[13]]
resoluion_lst = summerize['e_width'].unique()

for i in resoluion_lst:
        Res = summerize[summerize['e_width']==i]
        Res = Res.sort_values(by=['t_average_bitrate'])
        x = Res['t_average_bitrate']
        y = Res['t_average_vmaf']
        ax[3, 2].plot(x, y, label=i)
        ax[3, 2].title.set_text(uniq[13])
                        
# finding x and y axis for our convex hull

x = summerize['t_average_bitrate']
y = summerize['t_average_vmaf']
x_lst = pd.Series(x).values
y_lst = pd.Series(y).values
x_lst_S = x_lst.reshape(78,1)
y_lst_S = y_lst.reshape(78,1)
xy = np.concatenate((x_lst_S, y_lst_S), axis=1)


# plot convex hull for axis

hull = ConvexHull(xy)
for sample in hull.simplices:
    ax[3, 2].plot(xy[sample, 0], xy[sample, 1], 'r', label=i, linewidth=2)
               


summerize=data_set[data_set['c_content_category']==uniq[14]]
resoluion_lst = summerize['e_width'].unique()
               
for i in resoluion_lst:
        Res = summerize[summerize['e_width']==i]
        Res = Res.sort_values(by=['t_average_bitrate'])
        x = Res['t_average_bitrate']
        y = Res['t_average_vmaf']
        ax[4, 2].plot(x, y, label=i)
        ax[4, 2].title.set_text(uniq[14])
                        
# finding x and y axis for our convex hull

x = summerize['t_average_bitrate']
y = summerize['t_average_vmaf']
x_lst = pd.Series(x).values
y_lst = pd.Series(y).values
x_lst_S = x_lst.reshape(1716,1)
y_lst_S = y_lst.reshape(1716,1)
xy = np.concatenate((x_lst_S, y_lst_S), axis=1)


plt.legend(title='Resolution')
plt.tight_layout()

# plot convex hull for axis

hull = ConvexHull(xy)
for sample in hull.simplices:
    ax[4, 2].plot(xy[sample, 0], xy[sample, 1], 'r', label=i, linewidth=2)

plt.tight_layout()
